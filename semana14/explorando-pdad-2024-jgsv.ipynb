# %% [markdown]
# # Exercício 1.1 — Lendo os dados

# %%
import pandas as pd

pd.read_csv("moradores.csv", sep=";", decimal=",", encoding="utf-8-sig")
# Out:
# /tmp/ipykernel_11511/983406614.py:3: DtypeWarning: Columns (12,14) have mixed types. Specify dtype option on import or set low_memory=False.
#   pd.read_csv("moradores.csv", sep=";", decimal=",", encoding="utf-8-sig")
#        A01nficha  A01uf  localidade  setor_distrito morador_id  index  \
# 0              1     53        5330              35    00001-1      1
# 1              2     53        5320              24    00002-1      1
# 2              2     53        5320              24    00002-2      2
# 3              2     53        5320              24    00002-3      3
# 4              2     53        5320              24    00002-4      4
# ...          ...    ...         ...             ...        ...    ...
# 30680      10939     53        5327              32    10939-2      2
# 30681      10940     53        5302               5    10940-1      1
# 30682      10940     53        5302               5    10940-2      2
# ...

# %% [markdown]
# # utiizando a função help() para obter informações

# %%
help("pandas.read_csv")
# Out:
# Help on function read_csv in pandas:
#
# ...

# %%
moradores = pd.read_csv("moradores.csv", sep=";", decimal=",", encoding="utf-8-sig")
# Out:
# /tmp/ipykernel_1528/1571259067.py:1: DtypeWarning: Columns (12,14) have mixed types. Specify dtype option on import or set low_memory=False.
#   moradores = pd.read_csv("moradores.csv", sep=";", decimal=",", encoding="utf-8-sig")

# %%
type(moradores)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# setando low profile = false na função reaa_csv

# %%
moradores = pd.read_csv("moradores.csv", sep=";", decimal=",", encoding="utf-8-sig", low_memory=False)
print(moradores)
# Out:
#        A01nficha  A01uf  localidade  setor_distrito morador_id  index  \
# 0              1     53        5330              35    00001-1      1
# 1              2     53        5320              24    00002-1      1
# 2              2     53        5320              24    00002-2      2
# 3              2     53        5320              24    00002-3      3
# 4              2     53        5320              24    00002-4      4
# ...          ...    ...         ...             ...        ...    ...
# 69537      24844     53        5319              23    24844-2      2
# 69538      24844     53        5319              23    24844-3      3
# 69539      24844     53        5319              23    24844-4      4
# 69540      24845     52        5249              46    24845-1      1
# 69541      24845     52        5249              46    24845-2      2
#
#        idade_calculada       E02_1  E02_2  E02_3  ...  I22_2_r    I23  \
# ...

# %% [markdown]
# # Exercício 1.2 — Selecionando colunas

# %%
colunas = ["morador_id",  "localidade",  "idade_calculada" , "peso_mor"]
print(type(colunas))
print(type(moradores[colunas]))
print(moradores[colunas])
# Out:
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
#       morador_id  localidade  idade_calculada    peso_mor
# 0        00001-1        5330               49   78.620213
# 1        00002-1        5320               35  148.818895
# 2        00002-2        5320               41  212.895183
# 3        00002-3        5320                5  341.500430
# 4        00002-4        5320                3  244.902648
# ...          ...         ...              ...         ...
# 69537    24844-2        5319               11   14.546175
# 69538    24844-3        5319                7   13.599044
# 69539    24844-4        5319                7   15.464007
# 69540    24845-1        5249               97   10.617782
# 69541    24845-2        5249               51    9.421413
#
# [69542 rows x 4 columns]

# %% [markdown]
# # Exercício 1.3 — Contando moradores por domicílio

# %%
import pandas as pd

domicilios = pd.read_excel("domicilios.xlsx")

# %%
print(type(domicilios.iterrows()))
print(domicilios.iterrows())
# Out:
# <class 'generator'>
# <generator object DataFrame.iterrows at 0x78a58900a460>

# %%
import pandas as pd

domicilios = pd.read_excel("domicilios.xlsx")

for _, linha in domicilios.iterrows():
    print(f"Domicílio {linha['A01nficha']}: {linha['A01npessoas']} moradores, {linha['A01ncriancas']} crianças")
# Out:
# A saída de streaming foi truncada nas últimas 5000 linhas.
# Domicílio 19846: 4 moradores, 1 crianças
# Domicílio 19847: 3 moradores, 1 crianças
# Domicílio 19848: 2 moradores, 0 crianças
# Domicílio 19849: 2 moradores, 0 crianças
# Domicílio 19850: 3 moradores, 0 crianças
# Domicílio 19851: 2 moradores, 0 crianças
# Domicílio 19852: 3 moradores, 0 crianças
# Domicílio 19853: 4 moradores, 1 crianças
# Domicílio 19854: 2 moradores, 0 crianças
# Domicílio 19855: 2 moradores, 0 crianças
# Domicílio 19856: 5 moradores, 1 crianças
# Domicílio 19857: 2 moradores, 0 crianças
# Domicílio 19858: 4 moradores, 2 crianças
# Domicílio 19859: 1 moradores, 0 crianças
# Domicílio 19860: 5 moradores, 0 crianças
# Domicílio 19861: 1 moradores, 0 crianças
# Domicílio 19862: 3 moradores, 1 crianças
# Domicílio 19863: 1 moradores, 0 crianças
# Domicílio 19864: 8 moradores, 4 crianças
# Domicílio 19865: 5 moradores, 1 crianças
# Domicílio 19866: 5 moradores, 0 crianças
# ...

# %% [markdown]
# # Exercício 1.4 — Exibindo idades
#
# - Objetivo: Listar todas as idades dos moradores, excluindo o valor 99999.
#
# - O que aprender: Filtragem simples com condição booleana.

# %%
adultos = moradores[moradores["idade_calculada"] != 99999]
print(adultos[["morador_id", "idade_calculada"]])
# Out:
#       morador_id  idade_calculada
# 0        00001-1               49
# 1        00002-1               35
# 2        00002-2               41
# 3        00002-3                5
# 4        00002-4                3
# ...          ...              ...
# 69537    24844-2               11
# 69538    24844-3                7
# 69539    24844-4                7
# 69540    24845-1               97
# 69541    24845-2               51
#
# [69542 rows x 2 columns]

# %%
idades = moradores[moradores["idade_calculada"] != 99999]["idade_calculada"].tolist()

soma = 0
for idade in idades:
    soma = soma + idade

media = soma / len(idades)
print(f"Total de moradores com idade declarada: {len(idades)}")
print(f"Soma das idades: {soma}")
print(f"Média de idade: {media:.1f} anos")
# Out:
# Total de moradores com idade declarada: 69542
# Soma das idades: 2518823
# Média de idade: 36.2 anos

# %%
escolaridade_nome = {
    1: "Sem instrução",
    2: "Fundamental incompleto",
    3: "Fundamental completo",
    4: "Médio incompleto",
    5: "Médio completo",
    6: "Superior incompleto",
    7: "Superior completo",
    8: "Sem classificação",
}

contagem = {}
for _, linha in moradores.iterrows():
    nivel = linha["escolaridade"]
    if nivel in escolaridade_nome:
        if nivel not in contagem:
            contagem[nivel] = 0
        contagem[nivel] += 1

print("Escolaridade dos moradores:")
for nivel, total in contagem.items():
    print(f"  {escolaridade_nome[nivel]}: {total} moradores")
# Out:
# Escolaridade dos moradores:
#   Médio completo: 15351 moradores
#   Superior completo: 13575 moradores
#   Sem instrução: 4231 moradores
#   Sem classificação: 6323 moradores
#   Fundamental incompleto: 17680 moradores
#   Médio incompleto: 5662 moradores
#   Superior incompleto: 4055 moradores
#   Fundamental completo: 2665 moradores

# %%
ra_alvo = 5320  # Gama

filtro = moradores[moradores["localidade"] == ra_alvo]

print(f"Moradores da RA {ra_alvo}:")
for _, linha in filtro.iterrows():
    print(f"  {linha['morador_id']} — {linha['idade_calculada']} anos — escolaridade: {linha['escolaridade']}")
# Out:
# Moradores da RA 5320:
#   00002-1 — 35 anos — escolaridade: 7
#   00002-2 — 41 anos — escolaridade: 7
#   00002-3 — 5 anos — escolaridade: 1
#   00002-4 — 3 anos — escolaridade: 1
#   00141-1 — 31 anos — escolaridade: 7
#   00141-2 — 38 anos — escolaridade: 7
#   00147-1 — 54 anos — escolaridade: 7
#   00147-2 — 50 anos — escolaridade: 7
#   00188-1 — 35 anos — escolaridade: 7
#   00206-1 — 46 anos — escolaridade: 7
#   00222-1 — 52 anos — escolaridade: 7
#   00222-2 — 53 anos — escolaridade: 7
#   00222-3 — 16 anos — escolaridade: 4
#   00222-4 — 13 anos — escolaridade: 2
#   00258-1 — 42 anos — escolaridade: 7
#   00258-2 — 44 anos — escolaridade: 7
#   00258-3 — 8 anos — escolaridade: 2
#   00607-1 — 47 anos — escolaridade: 7
#   00607-2 — 46 anos — escolaridade: 7
#   00607-3 — 9 anos — escolaridade: 2
#   00607-4 — 15 anos — escolaridade: 4
#   00669-1 — 41 anos — escolaridade: 7
#   00669-2 — 39 anos — escolaridade: 7
#   00765-1 — 42 anos — escolaridade: 7
# ...

# %% [markdown]
# ## 🔴 Nível 4 — Avançado (Relatórios via CLI)

# %%
import pandas as pd

def carregar_dados():
  # dataframe de moradores
  moradores = pd.read_csv("moradores.csv", sep=";", decimal=",", encoding="utf-8")

  # dataframe de domicilios
  dataframe_domicilios = pd.read_excel("domicilios.xlsx")

  return moradores, domicilios
def relatorio_idades(moradores):
  # dataframe dos moradores, excluido os que tem a idade_calculada = 99999
  validos = moradores[moradores["idade_calculada"]!= 99999]

  # serie (coluna de um dataframe) de idade_calculada
  serie_idades = validos["idade_calculada"]

  # lista de idades
  idades = serie_idades.tolist()

  print(f"Total de moradores com a idade registrada: {len(idades)}.")
  print(f"Média de idades: {sum(idades)/len(idades):.1f} anos.")
  print(f"Idade do morador mais novo: {min(idades)}.")
  print(f"Idade do morador mais velho: {max(idades)}.")

  def relatorio_escolaridade():
# Out:
#   File "/tmp/ipykernel_3958/212763811.py", line 26
#     def relatorio_escolaridade():
#                                  ^
# SyntaxError: incomplete input

# %%
def relatorio_idades(moradores):
  # dataframe dos moradores, excluido os que tem a idade_calculada = 99999
  validos = moradores[moradores["idade_calculada"]!= 99999]

  # serie (coluna de um dataframe) de idade_calculada
  serie_idades = validos["idade_calculada"]

  # lista de idades
  idades = serie_idades.tolist()

  print(f"Total de moradores com a idade registrada: {len(idades)}.")
  print(f"Média de idades: {sum(idades)/len(idades):.1f} anos.")
  print(f"Idade do morador mais novo: {min(idades)}")
  print(f"Idade do morador mais velho: {max(idades)}")
relatorio_idades(moradores)
# Out:
# Total de moradores com a idade registrada: 69542.
# Média de idades: 36.2 anos.
# Idade do morador mais novo: 0
# Idade do morador mais velho: 107

# %%
import tkinter as tk

# %%
janela = tk.Tk()
# Out:
# ---------------------------------------------------------------------------
# TclError                                  Traceback (most recent call last)
# /tmp/ipykernel_1165/939054756.py in <cell line: 0>()
# ----> 1 janela = tk.Tk()
#
# /usr/lib/python3.12/tkinter/__init__.py in __init__(self, screenName, baseName, className, useTk, sync, use)
#    2347                 baseName = baseName + ext
#    2348         interactive = False
# -> 2349         self.tk = _tkinter.create(screenName, baseName, className, interactive, wantobjects, useTk, sync, use)
#    2350         if _debug:
#    2351             self.tk.settrace(_print_command)
#
# TclError: no display name and no $DISPLAY environment variable
